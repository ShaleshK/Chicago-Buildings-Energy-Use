# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import datetime as dt
import csv
from api_keys import api_key

# %%
# buildings_csv = pd.read_csv("Buildings.csv")
# ids = buildings_csv["ID"]
buildings = []
# buildings_csv.head()
data_year = []
# ID = response['id']
# name = response['property_name']
# address = response['address']
# zipcode = response['zip_code']
# community = response['community_area']
# prop_type = response['primary_property_type']
# sq_ft = response['gross_floor_area_buildings_sq_ft']
# year_built = response['year_built']
# num_buildings = response['of_buildings']
# elec_kbtu = response['electricity_use_kbtu']
# gas_kbtu = response['natural_gas_use_kbtu']
# site_eui_kbtu_sq_ft = response['site_eui_kbtu_sq_ft']
# source_eui = response["source_eui_kbtu_sq_ft"]
# wn_site_eui = ["weather_normalized_site_eui_kbtu_sq_ft"]
# wn_source_eui = ["weather_normalized_source_eui_kbtu_sq_ft"]
# emissions = ["total_ghg_emissions_metric_tons_co2e"]
# intensity = ["ghg_intensity_kg_co2e_sq_ft"] 
# lat = response['latitude']
# lon = response['longitude']

# %%
response = requests.get("https://data.cityofchicago.org/resource/xq83-jr8c").json()
for i in range(len(response)):
#     try:
        data_year = response[i]['data_year']
        print(data_year)
        ID = response[i]['id']
        print(ID)
        name = response[i]['property_name']
        print(name)
        address = response[i]['address']
        print(address)
        zipcode = response[i]['zip_code']
        print(zipcode)
        community = response[i]['community_area']
        print(community)
        prop_type = response[i]['primary_property_type']
        print(prop_type)
        sq_ft = response[i]['gross_floor_area_buildings_sq_ft']
        print(sq_ft)
        year_built = response[i]['year_built']
        print(year_built)
        num_buildings = response[i]['of_buildings']
        print(num_buildings)
        elec_kbtu = response[i]['electricity_use_kbtu']
        print(elec_kbtu)
        gas_kbtu = response[i]['natural_gas_use_kbtu']
        print(gas_kbtu)
        site_eui = response[i]['site_eui_kbtu_sq_ft']
        print(site_eui)
        source_eui = response[i]["source_eui_kbtu_sq_ft"]
        print(source_eui)
        wn_site_eui = response[i]["weather_normalized_site_eui_kbtu_sq_ft"]
        print(wn_site_eui)
        wn_source_eui = response[i]["weather_normalized_source_eui_kbtu_sq_ft"]
        print(wn_source_eui)
        emissions = response[i]["total_ghg_emissions_metric_tons_co2e"]
        print(emissions)
        intensity = response[i]["ghg_intensity_kg_co2e_sq_ft"] 
        print(intensity)
        lat = response[i]['latitude']
        print(lat)
        lon = response[i]['longitude']
        print(lon)
        buildings.append({"Data Year": data_year,"ID": ID, "name": name,"Address":address,"Zip Code":zipcode, \
                          "Lat": lat, "Lon": lon,  "Community Area":community, "Property Type":prop_type, \
                         "Square Feet": sq_ft, "Year Built": year_built, "Num of Buildings": num_buildings, \
                         "Electricity KBTU": elec_kbtu, "Natural Gas KBTU": gas_kbtu, "Site_EUI": site_eui, \
                         "Source EUI": source_eui, "Weather Normalized Site EUI": wn_site_eui, \
                         "Weather Normalized Source EUI": wn_source_eui, "Emissions": emissions, "Intensity": intensity})
#         print(f'{response["name"]} {response["id"]}')
#     except:
#         print(f'city not found')
#         pass
# Out:
# 2015
# 250009
# Malcolm X College
# 1900 West Van Buren Street
# 60612
# NEAR WEST SIDE
# College/University
# 541575
# 1971
# 1
# 25403152
# 29511031
# 101.4
# 204.5
# 105.5
# 208.1
# 6671
# 12.3
# 41.876251000000003
# -87.674126999999999
# 2015
# 250127
# Bernard Mitchell Hospital
# 5815 S. Maryland Av.
# 60637
# HYDE PARK
# Hospital (General Medical & Surgical)
# 430772
# 1983
# 1
# 50618112
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-307d5ce87cc8> in <module>
#      24         elec_kbtu = response[i]['electricity_use_kbtu']
#      25         print(elec_kbtu)
# ---> 26         gas_kbtu = response[i]['natural_gas_use_kbtu']
#      27         print(gas_kbtu)
#      28         site_eui = response[i]['site_eui_kbtu_sq_ft']
#
# KeyError: 'natural_gas_use_kbtu'

# %%
# buildings = pd.DataFrame(buildings).from_dict()
buildings
# Out:
# [{'Data Year': '2015',
#   'ID': '250009',
#   'name': 'Malcolm X College',
#   'Address': '1900 West Van Buren Street',
#   'Zip Code': '60612',
#   'Lat': '41.876251000000003',
#   'Lon': '-87.674126999999999',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'College/University',
#   'Square Feet': '541575',
#   'Year Built': '1971',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '25403152',
#   'Natural Gas KBTU': '29511031',
#   'Site_EUI': '101.4',
#   'Source EUI': '204.5',
#   'Weather Normalized Site EUI': '105.5',
#   'Weather Normalized Source EUI': '208.1',
#   'Emissions': '6671',
#   'Intensity': '12.3'},
#  {'Data Year': '2015',
#   'ID': '251337',
#   'name': 'The Theatre School',
#   'Address': '2350 N. Racine',
#   'Zip Code': '60614',
#   'Lat': '41.924672000000001',
#   'Lon': '-87.658471000000006',
#   'Community Area': 'LINCOLN PARK',
#   'Property Type': 'College/University',
#   'Square Feet': '163000',
#   'Year Built': '2013',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '5526792',
#   'Natural Gas KBTU': '6892302',
#   'Site_EUI': '76.2',
#   'Source EUI': '150.9',
#   'Weather Normalized Site EUI': '77.599999999999994',
#   'Weather Normalized Source EUI': '151.80000000000001',
#   'Emissions': '1477',
#   'Intensity': '9.1'},
#  {'Data Year': '2015',
#   'ID': '250051',
#   'name': 'Simeon Caree-CPS',
#   'Address': '8235 S VINCENNES AVE',
#   'Zip Code': '60620',
#   'Lat': '41.744236000000001',
#   'Lon': '-87.635863000000001',
#   'Community Area': 'CHATHAM',
#   'Property Type': 'K-12 School',
#   'Square Feet': '284691',
#   'Year Built': '2003',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '13717564',
#   'Natural Gas KBTU': '16385844',
#   'Site_EUI': '105.7',
#   'Source EUI': '211.7',
#   'Weather Normalized Site EUI': '109.6',
#   'Weather Normalized Source EUI': '214.3',
#   'Emissions': '3626',
#   'Intensity': '12.7'},
#  {'Data Year': '2015',
#   'ID': '138605',
#   'name': 'Kennedy Plaza BK, L.L.C.',
#   'Address': '3300 W. Belmont Avenue',
#   'Zip Code': '60618',
#   'Lat': '41.939346999999998',
#   'Lon': '-87.710159000000004',
#   'Community Area': 'AVONDALE',
#   'Property Type': 'Strip Mall',
#   'Square Feet': '77385',
#   'Year Built': '1977',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '4925454',
#   'Natural Gas KBTU': '3810800',
#   'Site_EUI': '112.9',
#   'Source EUI': '251.6',
#   'Weather Normalized Site EUI': '112.9',
#   'Weather Normalized Source EUI': '251.6',
#   'Emissions': '1192',
#   'Intensity': '15.4'},
#  {'Data Year': '2015',
#   'ID': '176021',
#   'name': 'MetraMarket of Chicago',
#   'Address': '118 N. Canal Street',
#   'Zip Code': '60661',
#   'Lat': '41.883698000000003',
#   'Lon': '-87.639810999999995',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Mixed Use Property',
#   'Square Feet': '62792',
#   'Year Built': '2006',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '9587659',
#   'Natural Gas KBTU': '7981279',
#   'Site_EUI': '279.8',
#   'Source EUI': '612.9',
#   'Weather Normalized Site EUI': '292.3',
#   'Weather Normalized Source EUI': '630.29999999999995',
#   'Emissions': '2350',
#   'Intensity': '37.4'},
#  {'Data Year': '2015',
#   'ID': '251312',
#   'name': '#1961 Elston/Leavitt',
#   'Address': '2542 Elston Ave',
#   'Zip Code': '60622',
#   'Lat': '41.927701999999996',
#   'Lon': '-87.681329000000005',
#   'Community Area': 'LOGAN SQUARE',
#   'Property Type': 'Retail Store',
#   'Square Feet': '119178',
#   'Year Built': '2002',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '6559580',
#   'Natural Gas KBTU': '3591695',
#   'Site_EUI': '85.2',
#   'Source EUI': '204.5',
#   'Weather Normalized Site EUI': '87.6',
#   'Weather Normalized Source EUI': '207',
#   'Emissions': '1509',
#   'Intensity': '12.7'},
#  {'Data Year': '2015',
#   'ID': '251214',
#   'name': 'Wilson Yard',
#   'Address': '1026-1032 W Montrose',
#   'Zip Code': '60613',
#   'Lat': '41.961818000000001',
#   'Lon': '-87.655469999999994',
#   'Community Area': 'UPTOWN',
#   'Property Type': 'Mixed Use Property',
#   'Square Feet': '420494',
#   'Year Built': '2010',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '16341238',
#   'Natural Gas KBTU': '13235718',
#   'Site_EUI': '70.3',
#   'Source EUI': '155.1',
#   'Weather Normalized Site EUI': '72.099999999999994',
#   'Weather Normalized Source EUI': '157',
#   'Emissions': '3986',
#   'Intensity': '9.5'},
#  {'Data Year': '2015',
#   'ID': '100851',
#   'name': '600 West Chicago',
#   'Address': '600 West Chicago Avenue',
#   'Zip Code': '60654',
#   'Lat': '41.896501000000001',
#   'Lon': '-87.642880000000005',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '1670702',
#   'Year Built': '1908',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '116348313',
#   'Natural Gas KBTU': '4108670',
#   'Site_EUI': '85.5',
#   'Source EUI': '234.6',
#   'Weather Normalized Site EUI': '86.1',
#   'Weather Normalized Source EUI': '237.4',
#   'Emissions': '24771',
#   'Intensity': '14.8'},
#  {'Data Year': '2015',
#   'ID': '251408',
#   'name': 'Clissold Ele-CPS',
#   'Address': '2330 W 110th Pl',
#   'Zip Code': '60643',
#   'Lat': '41.692987000000002',
#   'Lon': '-87.679776000000004',
#   'Community Area': 'MORGAN PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '63257',
#   'Year Built': '2001',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1009846',
#   'Natural Gas KBTU': '2715219',
#   'Site_EUI': '58.9',
#   'Source EUI': '95.2',
#   'Weather Normalized Site EUI': '63',
#   'Weather Normalized Source EUI': '99.8',
#   'Emissions': '347',
#   'Intensity': '5.5'},
#  {'Data Year': '2015',
#   'ID': '160450',
#   'name': 'Sono East',
#   'Address': '840 West Blackhawk',
#   'Zip Code': '60642',
#   'Lat': '41.908557000000002',
#   'Lon': '-87.649735000000007',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '317997',
#   'Year Built': '2012',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '12688890',
#   'Natural Gas KBTU': '18588287',
#   'Site_EUI': '98.4',
#   'Source EUI': '186.7',
#   'Weather Normalized Site EUI': '100.7',
#   'Weather Normalized Source EUI': '188',
#   'Emissions': '3537',
#   'Intensity': '11.1'},
#  {'Data Year': '2015',
#   'ID': '250077',
#   'name': 'Wentworth Gardens',
#   'Address': '3770 S. WENTWORTH AVE',
#   'Zip Code': '60609',
#   'Lat': '41.826081000000002',
#   'Lon': '-87.631398000000004',
#   'Community Area': 'ARMOUR SQUARE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '838253',
#   'Year Built': '1947',
#   'Num of Buildings': '32',
#   'Electricity KBTU': '11678877',
#   'Natural Gas KBTU': '33990300',
#   'Site_EUI': '54.5',
#   'Source EUI': '86.3',
#   'Weather Normalized Site EUI': '55.6',
#   'Weather Normalized Source EUI': '87.5',
#   'Emissions': '4152',
#   'Intensity': '5'},
#  {'Data Year': '2015',
#   'ID': '135060',
#   'name': 'American Library Association',
#   'Address': '40-50 E. Huron',
#   'Zip Code': '60611',
#   'Lat': '41.894924000000003',
#   'Lon': '-87.626552000000004',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '104122',
#   'Year Built': '1960',
#   'Num of Buildings': '2',
#   'Electricity KBTU': '6094282',
#   'Natural Gas KBTU': '34812',
#   'Site_EUI': '58.9',
#   'Source EUI': '184.1',
#   'Weather Normalized Site EUI': '60.4',
#   'Weather Normalized Source EUI': '189',
#   'Emissions': '1226',
#   'Intensity': '11.8'},
#  {'Data Year': '2015',
#   'ID': '251593',
#   'name': 'Clay Element-CPS',
#   'Address': '13221 S Burley',
#   'Zip Code': '60633',
#   'Lat': '41.655085999999997',
#   'Lon': '-87.544685999999999',
#   'Community Area': 'HEGEWISCH',
#   'Property Type': 'K-12 School',
#   'Square Feet': '81950',
#   'Year Built': '1917',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1373141',
#   'Natural Gas KBTU': '6721988',
#   'Site_EUI': '98.8',
#   'Source EUI': '138.69999999999999',
#   'Weather Normalized Site EUI': '107.5',
#   'Weather Normalized Source EUI': '148.5',
#   'Emissions': '633',
#   'Intensity': '7.7'},
#  {'Data Year': '2015',
#   'ID': '134776',
#   'name': 'University Club of Chicago',
#   'Address': '76 East Monroe Street',
#   'Zip Code': '60603',
#   'Lat': '41.880837999999997',
#   'Lon': '-87.624993000000003',
#   'Community Area': 'LOOP',
#   'Property Type': 'Hotel',
#   'Square Feet': '144036',
#   'Year Built': '1907',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '9906479',
#   'Natural Gas KBTU': '24285377',
#   'Site_EUI': '237.4',
#   'Source EUI': '393',
#   'Weather Normalized Site EUI': '240.5',
#   'Weather Normalized Source EUI': '394.9',
#   'Emissions': '3280',
#   'Intensity': '22.8'},
#  {'Data Year': '2015',
#   'ID': '173495',
#   'name': 'Saint Juliana School',
#   'Address': '7400 West Touhy',
#   'Zip Code': '60631',
#   'Lat': '42.011611000000002',
#   'Lon': '-87.811524000000006',
#   'Community Area': 'EDISON PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '57011',
#   'Year Built': '1928',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '823015',
#   'Natural Gas KBTU': '5351810',
#   'Site_EUI': '108.3',
#   'Source EUI': '143.9',
#   'Weather Normalized Site EUI': '111.5',
#   'Weather Normalized Source EUI': '147.4',
#   'Emissions': '450',
#   'Intensity': '7.9'},
#  {'Data Year': '2015',
#   'ID': '160151',
#   'name': 'Clargran',
#   'Address': '501-515 N. Clark St.',
#   'Zip Code': '60654',
#   'Lat': '41.891371999999997',
#   'Lon': '-87.631065000000007',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Hotel',
#   'Square Feet': '343240',
#   'Year Built': '2013',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '18067639',
#   'Natural Gas KBTU': '23918101',
#   'Site_EUI': '122.3',
#   'Source EUI': '238.5',
#   'Weather Normalized Site EUI': '123.7',
#   'Weather Normalized Source EUI': '238.3',
#   'Emissions': '4900',
#   'Intensity': '14.3'},
#  {'Data Year': '2015',
#   'ID': '242172',
#   'name': 'Two East Oak Condominium Association',
#   'Address': 'Two East Oak Street',
#   'Zip Code': '60611',
#   'Lat': '41.900744000000003',
#   'Lon': '-87.628200000000007',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '253772',
#   'Year Built': '1971',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '8459614',
#   'Natural Gas KBTU': '17173129',
#   'Site_EUI': '101',
#   'Source EUI': '175.7',
#   'Weather Normalized Site EUI': '105.2',
#   'Weather Normalized Source EUI': '179.2',
#   'Emissions': '2612',
#   'Intensity': '10.3'},
#  {'Data Year': '2015',
#   'ID': '250017',
#   'name': 'Humboldt Park',
#   'Address': '1440 North Sacramento',
#   'Zip Code': '60622',
#   'Lat': '41.906756000000001',
#   'Lon': '-87.701357000000002',
#   'Community Area': 'NORTH LAWNDALE',
#   'Property Type': 'Other - Recreation',
#   'Square Feet': '57229',
#   'Year Built': '1928',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2506746',
#   'Natural Gas KBTU': '4593224',
#   'Site_EUI': '124.1',
#   'Source EUI': '221.8',
#   'Weather Normalized Site EUI': '130.6',
#   'Weather Normalized Source EUI': '228.7',
#   'Emissions': '748',
#   'Intensity': '13.1'},
#  {'Data Year': '2015',
#   'ID': '252023',
#   'name': 'CICS Longwood',
#   'Address': '1309 W. 95th St.',
#   'Zip Code': '60643',
#   'Lat': '41.721234000000003',
#   'Lon': '-87.655051999999998',
#   'Community Area': 'WASHINGTON HEIGHTS',
#   'Property Type': 'K-12 School',
#   'Square Feet': '165520',
#   'Year Built': '1952',
#   'Num of Buildings': '5',
#   'Electricity KBTU': '2001974',
#   'Natural Gas KBTU': '18099737',
#   'Site_EUI': '121.4',
#   'Source EUI': '152.80000000000001',
#   'Weather Normalized Site EUI': '130.19999999999999',
#   'Weather Normalized Source EUI': '162',
#   'Emissions': '1364',
#   'Intensity': '8.1999999999999993'},
#  {'Data Year': '2015',
#   'ID': '252046',
#   'name': 'Henry Crown Field House',
#   'Address': '5550 South University Ave.',
#   'Zip Code': '60637',
#   'Lat': '41.7941',
#   'Lon': '-87.598142999999993',
#   'Community Area': 'HYDE PARK',
#   'Property Type': 'Fitness Center/Health Club/Gym',
#   'Square Feet': '146501',
#   'Year Built': '1932',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '3584545',
#   'Natural Gas KBTU': '146450',
#   'Site_EUI': '61.8',
#   'Source EUI': '121.6',
#   'Weather Normalized Site EUI': '64.599999999999994',
#   'Weather Normalized Source EUI': '125',
#   'Emissions': '1082',
#   'Intensity': '7.4'},
#  {'Data Year': '2015',
#   'ID': '251946',
#   'name': '1010 Lake Shore Association',
#   'Address': '1000 N. Lake Shore Drive',
#   'Zip Code': '60611',
#   'Lat': '41.900883',
#   'Lon': '-87.624236999999994',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '253446',
#   'Year Built': '1954',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '9200110',
#   'Natural Gas KBTU': '14692701',
#   'Site_EUI': '94.3',
#   'Source EUI': '174.9',
#   'Weather Normalized Site EUI': '98.8',
#   'Weather Normalized Source EUI': '179.6',
#   'Emissions': '2629',
#   'Intensity': '10.4'},
#  {'Data Year': '2015',
#   'ID': '118892',
#   'name': 'Parc Chestnut Condominium Association',
#   'Address': '849 N Franklin St',
#   'Zip Code': '60610',
#   'Lat': '41.897733000000002',
#   'Lon': '-87.635683999999998',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '379568',
#   'Year Built': '2006',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '10583860',
#   'Natural Gas KBTU': '17804699',
#   'Site_EUI': '74.8',
#   'Source EUI': '136.80000000000001',
#   'Weather Normalized Site EUI': '76.900000000000006',
#   'Weather Normalized Source EUI': '138.19999999999999',
#   'Emissions': '3072',
#   'Intensity': '8.1'},
#  {'Data Year': '2015',
#   'ID': '250004',
#   'name': 'Kennedy-King College',
#   'Address': '6301 South Halsted',
#   'Zip Code': '60621',
#   'Lat': '41.779702999999998',
#   'Lon': '-87.644750999999999',
#   'Community Area': 'ENGLEWOOD',
#   'Property Type': 'College/University',
#   'Square Feet': '496817',
#   'Year Built': '2007',
#   'Num of Buildings': '6',
#   'Electricity KBTU': '36100427',
#   'Natural Gas KBTU': '56777310',
#   'Site_EUI': '186.9',
#   'Source EUI': '348.2',
#   'Weather Normalized Site EUI': '191.2',
#   'Weather Normalized Source EUI': '351.7',
#   'Emissions': '10269',
#   'Intensity': '20.7'},
#  {'Data Year': '2015',
#   'ID': '103669',
#   'name': 'Soldier Field',
#   'Address': '1410 South Museum Campus Drive',
#   'Zip Code': '60605',
#   'Lat': '41.863883999999999',
#   'Lon': '-87.614512000000005',
#   'Community Area': 'NEAR SOUTH SIDE',
#   'Property Type': 'Stadium (Open)',
#   'Square Feet': '1548634',
#   'Year Built': '1924',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '108529613',
#   'Natural Gas KBTU': '16899451',
#   'Site_EUI': '81',
#   'Source EUI': '231.5',
#   'Weather Normalized Site EUI': '82.7',
#   'Weather Normalized Source EUI': '235.7',
#   'Emissions': '22703',
#   'Intensity': '14.7'},
#  {'Data Year': '2015',
#   'ID': '100867',
#   'name': 'Rush University Medical Center',
#   'Address': '1653 West Congress Parkway',
#   'Zip Code': '60612',
#   'Lat': '41.875121',
#   'Lon': '-87.668004999999994',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Hospital (General Medical & Surgical)',
#   'Square Feet': '4098526',
#   'Year Built': '1982',
#   'Num of Buildings': '9',
#   'Electricity KBTU': '461845249',
#   'Natural Gas KBTU': '300796332',
#   'Site_EUI': '263.7',
#   'Source EUI': '524.29999999999995',
#   'Weather Normalized Site EUI': '266.89999999999998',
#   'Weather Normalized Source EUI': '525.70000000000005',
#   'Emissions': '129897',
#   'Intensity': '31.7'},
#  {'Data Year': '2015',
#   'ID': '251529',
#   'name': 'Lovett Eleme-CPS',
#   'Address': '6333 W Bloomingdale Ave',
#   'Zip Code': '60639',
#   'Lat': '41.912785999999997',
#   'Lon': '-87.78313',
#   'Community Area': 'AUSTIN',
#   'Property Type': 'K-12 School',
#   'Square Feet': '85200',
#   'Year Built': '1927',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1418738',
#   'Natural Gas KBTU': '5340524',
#   'Site_EUI': '79.3',
#   'Source EUI': '118.1',
#   'Weather Normalized Site EUI': '84.5',
#   'Weather Normalized Source EUI': '123.5',
#   'Emissions': '569',
#   'Intensity': '6.7'},
#  {'Data Year': '2015',
#   'ID': '117702',
#   'name': 'AceTechChrt-CPS',
#   'Address': '5400 S State St',
#   'Zip Code': '60609',
#   'Lat': '41.796360999999997',
#   'Lon': '-87.625781000000003',
#   'Community Area': 'WASHINGTON PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '68331',
#   'Year Built': '1963',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '677117',
#   'Natural Gas KBTU': '3525015',
#   'Site_EUI': '61.5',
#   'Source EUI': '85.3',
#   'Weather Normalized Site EUI': '65.3',
#   'Weather Normalized Source EUI': '89.3',
#   'Emissions': '323',
#   'Intensity': '4.7'},
#  {'Data Year': '2014',
#   'ID': '103620',
#   'name': 'Grossinger City Autoplex',
#   'Address': '1530 N Dayton St',
#   'Zip Code': '60642',
#   'Lat': '41.910106',
#   'Lon': '-87.649495',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Automobile Dealership',
#   'Square Feet': '275000',
#   'Year Built': '2008',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '11270379',
#   'Natural Gas KBTU': '5739722',
#   'Site_EUI': '62',
#   'Source EUI': '151',
#   'Weather Normalized Site EUI': '57',
#   'Weather Normalized Source EUI': '142',
#   'Emissions': '2569',
#   'Intensity': '9.34'},
#  {'Data Year': '2014',
#   'ID': '250046',
#   'name': 'Jones Colleg-CPS',
#   'Address': '600 S State St',
#   'Zip Code': '60605',
#   'Lat': '41.874294',
#   'Lon': '-87.627664',
#   'Community Area': 'LOOP',
#   'Property Type': 'K-12 School',
#   'Square Feet': '253266',
#   'Year Built': '1968',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '14403553',
#   'Natural Gas KBTU': '9339938',
#   'Site_EUI': '94',
#   'Source EUI': '217',
#   'Weather Normalized Site EUI': '88',
#   'Weather Normalized Source EUI': '208',
#   'Emissions': '3390',
#   'Intensity': '13.38'},
#  {'Data Year': '2014',
#   'ID': '101686',
#   'name': 'Harlem-Foster Shopping Center',
#   'Address': '7240 West Foster Avenue',
#   'Zip Code': '60656',
#   'Lat': '41.974578',
#   'Lon': '-87.808091',
#   'Community Area': 'NORWOOD PARK',
#   'Property Type': 'Strip Mall',
#   'Square Feet': '273613',
#   'Year Built': '1958',
#   'Num of Buildings': '30',
#   'Electricity KBTU': '20005795',
#   'Natural Gas KBTU': '18778584',
#   'Site_EUI': '142',
#   'Source EUI': '302',
#   'Weather Normalized Site EUI': '136',
#   'Weather Normalized Source EUI': '295',
#   'Emissions': '5017',
#   'Intensity': '18.34'},
#  {'Data Year': '2014',
#   'ID': '103611',
#   'name': 'Clark-Adams',
#   'Address': '105 W. Adams',
#   'Zip Code': '60603',
#   'Lat': '41.879395',
#   'Lon': '-87.630986',
#   'Community Area': 'LOOP',
#   'Property Type': 'Office',
#   'Square Feet': '490273',
#   'Year Built': '1927',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '22359198',
#   'Natural Gas KBTU': '35944627',
#   'Site_EUI': '119',
#   'Source EUI': '220',
#   'Weather Normalized Site EUI': '114',
#   'Weather Normalized Source EUI': '214',
#   'Emissions': '6401',
#   'Intensity': '13.06'},
#  {'Data Year': '2014',
#   'ID': '250138',
#   'name': 'Provident Hospital',
#   'Address': '500 E. 51st St.',
#   'Zip Code': '60615',
#   'Lat': '41.802169',
#   'Lon': '-87.613988',
#   'Community Area': 'GRAND BOULEVARD',
#   'Property Type': 'Hospital (General Medical & Surgical)',
#   'Square Feet': '373995',
#   'Year Built': '1981',
#   'Num of Buildings': '2',
#   'Electricity KBTU': '39238375',
#   'Natural Gas KBTU': '77699964',
#   'Site_EUI': '313',
#   'Source EUI': '548',
#   'Weather Normalized Site EUI': '302',
#   'Weather Normalized Source EUI': '535',
#   'Emissions': '12011',
#   'Intensity': '32.11'},
#  {'Data Year': '2014',
#   'ID': '103705',
#   'name': 'CentralOffic-CPS',
#   'Address': '125 S Clark St',
#   'Zip Code': '60603',
#   'Lat': '41.879992',
#   'Lon': '-87.630764',
#   'Community Area': 'LOOP',
#   'Property Type': 'Office',
#   'Square Feet': '502000',
#   'Year Built': '1900',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '17041309',
#   'Natural Gas KBTU': '19300137',
#   'Site_EUI': '72',
#   'Source EUI': '147',
#   'Weather Normalized Site EUI': '70',
#   'Weather Normalized Source EUI': '144',
#   'Emissions': '4449',
#   'Intensity': '8.86'},
#  {'Data Year': '2014',
#   'ID': '103608',
#   'name': '329 W 18th Street',
#   'Address': '329 W 18th Street',
#   'Zip Code': '60616',
#   'Lat': '41.857685',
#   'Lon': '-87.636254',
#   'Community Area': 'LOWER WEST SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '406780',
#   'Year Built': '1911',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '11287176',
#   'Natural Gas KBTU': '7229520',
#   'Site_EUI': '46',
#   'Source EUI': '106',
#   'Weather Normalized Site EUI': '44',
#   'Weather Normalized Source EUI': '103',
#   'Emissions': '2652',
#   'Intensity': '6.52'},
#  {'Data Year': '2014',
#   'ID': '101722',
#   'name': '500 West Monroe',
#   'Address': '500 West Monroe',
#   'Zip Code': '60661',
#   'Lat': '41.880609',
#   'Lon': '-87.639778',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '1153491',
#   'Year Built': '1992',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '63075187',
#   'Natural Gas KBTU': '680954',
#   'Site_EUI': '55',
#   'Source EUI': '172',
#   'Weather Normalized Site EUI': '52',
#   'Weather Normalized Source EUI': '162',
#   'Emissions': '12709',
#   'Intensity': '11.02'},
#  {'Data Year': '2014',
#   'ID': '103781',
#   'name': '625 N Michigan Avenue',
#   'Address': '625 N Michigan Avenue',
#   'Zip Code': '60611-4594',
#   'Lat': '41.893122',
#   'Lon': '-87.624155',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '359409',
#   'Year Built': '1969',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '14967898',
#   'Natural Gas KBTU': '14167900',
#   'Site_EUI': '81',
#   'Source EUI': '172',
#   'Weather Normalized Site EUI': '76',
#   'Weather Normalized Source EUI': '167',
#   'Emissions': '3760',
#   'Intensity': '10.46'},
#  {'Data Year': '2014',
#   'ID': '101551',
#   'name': 'METROPOLITIAN PIER AND EXPOSITION AUTHORITY',
#   'Address': '301 Cermak Road',
#   'Zip Code': '60616',
#   'Lat': '41.85284',
#   'Lon': '-87.634931',
#   'Community Area': 'ARMOUR SQUARE',
#   'Property Type': 'Convention Center',
#   'Square Feet': '9245333',
#   'Year Built': '1971',
#   'Num of Buildings': '8',
#   'Electricity KBTU': '485542954',
#   'Natural Gas KBTU': '344178866',
#   'Site_EUI': '90',
#   'Source EUI': '204',
#   'Weather Normalized Site EUI': '86',
#   'Weather Normalized Source EUI': '200',
#   'Emissions': '115833',
#   'Intensity': '12.53'},
#  {'Data Year': '2014',
#   'ID': '103630',
#   'name': 'Stroger Hospital Campus',
#   'Address': '1901 W. Harrison St.',
#   'Zip Code': '60612',
#   'Lat': '41.874071',
#   'Lon': '-87.674135',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Hospital (General Medical & Surgical)',
#   'Square Feet': '1802093',
#   'Year Built': '2002',
#   'Num of Buildings': '4',
#   'Electricity KBTU': '187764271',
#   'Natural Gas KBTU': '348611023',
#   'Site_EUI': '298',
#   'Source EUI': '530',
#   'Weather Normalized Site EUI': '290',
#   'Weather Normalized Source EUI': '523',
#   'Emissions': '56241',
#   'Intensity': '31.21'},
#  {'Data Year': '2014',
#   'ID': '103761',
#   'name': '20 West Kinzie',
#   'Address': '20 West Kinzie Street',
#   'Zip Code': '60654',
#   'Lat': '41.88927',
#   'Lon': '-87.628761',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '392653',
#   'Year Built': '2000',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '34878044',
#   'Natural Gas KBTU': '937661',
#   'Site_EUI': '91',
#   'Source EUI': '281',
#   'Weather Normalized Site EUI': '91',
#   'Weather Normalized Source EUI': '281',
#   'Emissions': '7057',
#   'Intensity': '17.97'},
#  {'Data Year': '2014',
#   'ID': '160196',
#   'name': 'The Art Institute of Chicago',
#   'Address': '111 South Michigan Ave',
#   'Zip Code': '60603',
#   'Lat': '41.880452',
#   'Lon': '-87.624229',
#   'Community Area': 'LOOP',
#   'Property Type': 'Museum',
#   'Square Feet': '1008416',
#   'Year Built': '1892',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '94822312',
#   'Natural Gas KBTU': '158283369',
#   'Site_EUI': '251',
#   'Source EUI': '460',
#   'Weather Normalized Site EUI': '248',
#   'Weather Normalized Source EUI': '457',
#   'Emissions': '27458',
#   'Intensity': '27.23'},
#  {'Data Year': '2014',
#   'ID': '103614',
#   'name': "Ann & Robert H. Lurie Children's Hospital of Chicago",
#   'Address': '225 E Chicago Ave',
#   'Zip Code': '60611',
#   'Lat': '41.896764',
#   'Lon': '-87.621559',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Hospital (General Medical & Surgical)',
#   'Square Feet': '1250000',
#   'Year Built': '2012',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '118414722',
#   'Natural Gas KBTU': '193087199',
#   'Site_EUI': '251',
#   'Source EUI': '461',
#   'Weather Normalized Site EUI': '244',
#   'Weather Normalized Source EUI': '451',
#   'Emissions': '34191',
#   'Intensity': '27.35'},
#  {'Data Year': '2014',
#   'ID': '167562',
#   'name': 'Lincoln Park-CPS',
#   'Address': '2016 N Orchard',
#   'Zip Code': '60614',
#   'Lat': '41.918361',
#   'Lon': '-87.646171',
#   'Community Area': 'LINCOLN PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '269474',
#   'Year Built': '1901',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '6449656',
#   'Natural Gas KBTU': '17111495',
#   'Site_EUI': '87',
#   'Source EUI': '142',
#   'Weather Normalized Site EUI': '80',
#   'Weather Normalized Source EUI': '133',
#   'Emissions': '2205',
#   'Intensity': '8.18'},
#  {'Data Year': '2014',
#   'ID': '103684',
#   'name': 'NMH Arkes Family Pavilion',
#   'Address': '676 N St. Clair St',
#   'Zip Code': '60611',
#   'Lat': '41.894419',
#   'Lon': '-87.622789',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Medical Office',
#   'Square Feet': '675000',
#   'Year Built': '1980',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '80105094',
#   'Natural Gas KBTU': '240000',
#   'Site_EUI': '119',
#   'Source EUI': '373',
#   'Weather Normalized Site EUI': '116',
#   'Weather Normalized Source EUI': '364',
#   'Emissions': '16107',
#   'Intensity': '23.86'},
#  {'Data Year': '2014',
#   'ID': '168174',
#   'name': 'Kelly High S-CPS',
#   'Address': '4136 S California Ave',
#   'Zip Code': '60632',
#   'Lat': '41.818909',
#   'Lon': '-87.694567',
#   'Community Area': 'BRIGHTON PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '298432',
#   'Year Built': '1928',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '8949806',
#   'Natural Gas KBTU': '17533370',
#   'Site_EUI': '89',
#   'Source EUI': '156',
#   'Weather Normalized Site EUI': '79',
#   'Weather Normalized Source EUI': '146',
#   'Emissions': '2729',
#   'Intensity': '9.15'},
#  {'Data Year': '2014',
#   'ID': '250051',
#   'name': 'Simeon Caree-CPS',
#   'Address': '8235 S VINCENNES AVE',
#   'Zip Code': '60620',
#   'Lat': '41.744236',
#   'Lon': '-87.635863',
#   'Community Area': 'CHATHAM',
#   'Property Type': 'K-12 School',
#   'Square Feet': '284691',
#   'Year Built': '2003',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '13609687',
#   'Natural Gas KBTU': '21476024',
#   'Site_EUI': '123',
#   'Source EUI': '229',
#   'Weather Normalized Site EUI': '117',
#   'Weather Normalized Source EUI': '222',
#   'Emissions': '3875',
#   'Intensity': '13.61'},
#  {'Data Year': '2014',
#   'ID': '112638',
#   'name': 'Juvenile Temporary Detention Center',
#   'Address': '1100 S. Hamilton Ave.',
#   'Zip Code': '60612',
#   'Lat': '41.867488',
#   'Lon': '-87.680301',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Prison/Incarceration',
#   'Square Feet': '611255',
#   'Year Built': '1974',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '27840525',
#   'Natural Gas KBTU': '32684480',
#   'Site_EUI': '99',
#   'Source EUI': '199',
#   'Weather Normalized Site EUI': '93',
#   'Weather Normalized Source EUI': '193',
#   'Emissions': '7330',
#   'Intensity': '11.99'},
#  {'Data Year': '2014',
#   'ID': '250009',
#   'name': 'Malcolm X College',
#   'Address': '1900 West Van Buren Street',
#   'Zip Code': '60612',
#   'Lat': '41.876251',
#   'Lon': '-87.674127',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'College/University',
#   'Square Feet': '541575',
#   'Year Built': '1971',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '26306288',
#   'Natural Gas KBTU': '36058949',
#   'Site_EUI': '115',
#   'Source EUI': '222',
#   'Weather Normalized Site EUI': '110',
#   'Weather Normalized Source EUI': '217',
#   'Emissions': '7201',
#   'Intensity': '13.3'},
#  {'Data Year': '2014',
#   'ID': '103634',
#   'name': "Lewis & O'Malley",
#   'Address': '25 E. Jackson Blvd.',
#   'Zip Code': '60604',
#   'Lat': '41.878202',
#   'Lon': '-87.626867',
#   'Community Area': 'LOOP',
#   'Property Type': 'College/University',
#   'Square Feet': '380371',
#   'Year Built': '1928',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '16119939',
#   'Natural Gas KBTU': '18287416',
#   'Site_EUI': '91',
#   'Source EUI': '184',
#   'Weather Normalized Site EUI': '87',
#   'Weather Normalized Source EUI': '180',
#   'Emissions': '4210',
#   'Intensity': '11.07'},
#  {'Data Year': '2014',
#   'ID': '100851',
#   'name': '600 W Chicago',
#   'Address': '600 W Chicago',
#   'Zip Code': '60654',
#   'Lat': '41.896501',
#   'Lon': '-87.64288',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '1434236',
#   'Year Built': '1908',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '119811664',
#   'Natural Gas KBTU': '2098799',
#   'Site_EUI': '98',
#   'Source EUI': '277',
#   'Weather Normalized Site EUI': '98',
#   'Weather Normalized Source EUI': '275',
#   'Emissions': '25200',
#   'Intensity': '17.57'},
#  {'Data Year': '2014',
#   'ID': '100256',
#   'name': 'Curie Metrop-CPS',
#   'Address': '4975 S Archer',
#   'Zip Code': '60632',
#   'Lat': '41.802759',
#   'Lon': '-87.722671',
#   'Community Area': 'ARCHER HEIGHTS',
#   'Property Type': 'K-12 School',
#   'Square Feet': '447330',
#   'Year Built': '1990',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '35792767',
#   'Natural Gas KBTU': '7180231',
#   'Site_EUI': '96',
#   'Source EUI': '268',
#   'Weather Normalized Site EUI': '93',
#   'Weather Normalized Source EUI': '261',
#   'Emissions': '7573',
#   'Intensity': '16.93'},
#  {'Data Year': '2014',
#   'ID': '250053',
#   'name': 'Taft High Sc-CPS',
#   'Address': '6545 W HURLBUT ST',
#   'Zip Code': '60634',
#   'Lat': '41.985587',
#   'Lon': '-87.791778',
#   'Community Area': 'NORWOOD PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '383500',
#   'Year Built': '1939',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '10491091',
#   'Natural Gas KBTU': '14444979',
#   'Site_EUI': '65',
#   'Source EUI': '125',
#   'Weather Normalized Site EUI': '61',
#   'Weather Normalized Source EUI': '121',
#   'Emissions': '2875',
#   'Intensity': '7.5'},
#  {'Data Year': '2014',
#   'ID': '103798',
#   'name': 'Federal Railroad Retirement Board',
#   'Address': '844 W. Rush Street',
#   'Zip Code': '60611',
#   'Lat': '41.897972',
#   'Lon': '-87.626633',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Office',
#   'Square Feet': '383007',
#   'Year Built': '1923',
#   'Num of Buildings': '4',
#   'Electricity KBTU': '16227158',
#   'Natural Gas KBTU': '24838132',
#   'Site_EUI': '107',
#   'Source EUI': '201',
#   'Weather Normalized Site EUI': '103',
#   'Weather Normalized Source EUI': '197',
#   'Emissions': '4580',
#   'Intensity': '11.96'},
#  {'Data Year': '2014',
#   'ID': '100867',
#   'name': 'Rush University Medical Center',
#   'Address': '1653 West Congress Parkway',
#   'Zip Code': '60612',
#   'Lat': '41.875121',
#   'Lon': '-87.668005',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Hospital (General Medical & Surgical)',
#   'Square Feet': '4098526',
#   'Year Built': '1982',
#   'Num of Buildings': '9',
#   'Electricity KBTU': '474588387',
#   'Natural Gas KBTU': '346243488',
#   'Site_EUI': '289',
#   'Source EUI': '560',
#   'Weather Normalized Site EUI': '285',
#   'Weather Normalized Source EUI': '554',
#   'Emissions': '138008',
#   'Intensity': '33.67'},
#  {'Data Year': '2014',
#   'ID': '103656',
#   'name': 'Merchandise Mart',
#   'Address': '222 Merchandise Mart Plaza',
#   'Zip Code': '60654',
#   'Lat': '41.888012',
#   'Lon': '-87.634543',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Mixed Use Property',
#   'Square Feet': '4146422',
#   'Year Built': '1930',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '135798726',
#   'Natural Gas KBTU': '95835487',
#   'Site_EUI': '66',
#   'Source EUI': '137',
#   'Weather Normalized Site EUI': '63',
#   'Weather Normalized Source EUI': '135',
#   'Emissions': '34627',
#   'Intensity': '8.35'},
#  {'Data Year': '2014',
#   'ID': '250004',
#   'name': 'Kennedy-King College',
#   'Address': '6301 South Halsted',
#   'Zip Code': '60621',
#   'Lat': '41.779703',
#   'Lon': '-87.644751',
#   'Community Area': 'ENGLEWOOD',
#   'Property Type': 'College/University',
#   'Square Feet': '496817',
#   'Year Built': '2007',
#   'Num of Buildings': '6',
#   'Electricity KBTU': '38312563',
#   'Natural Gas KBTU': '46358763',
#   'Site_EUI': '170',
#   'Source EUI': '340',
#   'Weather Normalized Site EUI': '167',
#   'Weather Normalized Source EUI': '336',
#   'Emissions': '10160',
#   'Intensity': '20.45'},
#  {'Data Year': '2015',
#   'ID': '251773',
#   'name': '03296-Foster & Harlem',
#   'Address': '7342 Foster Ave',
#   'Zip Code': '60656',
#   'Lat': '41.974474000000001',
#   'Lon': '-87.810635000000005',
#   'Community Area': 'NORWOOD PARK',
#   'Property Type': 'Supermarket/Grocery Store',
#   'Square Feet': '77255',
#   'Year Built': '1978',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '9338682',
#   'Natural Gas KBTU': '4866600',
#   'Site_EUI': '183.9',
#   'Source EUI': '445.7',
#   'Weather Normalized Site EUI': '185.4',
#   'Weather Normalized Source EUI': '446.5',
#   'Emissions': '2135',
#   'Intensity': '27.6'},
#  {'Data Year': '2015',
#   'ID': '250014',
#   'name': 'Mann Park',
#   'Address': '2949 East 131st Street',
#   'Zip Code': '60633',
#   'Lat': '41.657316000000002',
#   'Lon': '-87.552719999999994',
#   'Community Area': 'HEGEWISCH',
#   'Property Type': 'Other - Recreation',
#   'Square Feet': '51273',
#   'Year Built': '1934',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1391755',
#   'Natural Gas KBTU': '5915773',
#   'Site_EUI': '142.5',
#   'Source EUI': '206.4',
#   'Weather Normalized Site EUI': '150.69999999999999',
#   'Weather Normalized Source EUI': '215',
#   'Emissions': '594',
#   'Intensity': '11.6'},
#  {'Data Year': '2015',
#   'ID': '251404',
#   'name': 'Burr Element-CPS',
#   'Address': '1621 W Wabansia Ave',
#   'Zip Code': '60622',
#   'Lat': '41.912405',
#   'Lon': '-87.668588999999997',
#   'Community Area': 'WEST TOWN',
#   'Property Type': 'K-12 School',
#   'Square Feet': '60929',
#   'Year Built': '1890',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '925141',
#   'Natural Gas KBTU': '3633077',
#   'Site_EUI': '74.8',
#   'Source EUI': '110.3',
#   'Weather Normalized Site EUI': '79.7',
#   'Weather Normalized Source EUI': '115.7',
#   'Emissions': '379',
#   'Intensity': '6.2'},
#  {'Data Year': '2015',
#   'ID': '160372',
#   'name': 'AMLI River North',
#   'Address': '71 West Hubbard St',
#   'Zip Code': '60654',
#   'Lat': '41.890020999999997',
#   'Lon': '-87.630345000000005',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '456710',
#   'Year Built': '2013',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '11380941',
#   'Natural Gas KBTU': '9949551',
#   'Site_EUI': '46.7',
#   'Source EUI': '101.1',
#   'Weather Normalized Site EUI': '47.8',
#   'Weather Normalized Source EUI': '102.3',
#   'Emissions': '2815',
#   'Intensity': '6.2'},
#  {'Data Year': '2015',
#   'ID': '250118',
#   'name': 'Norwegian American Hospital',
#   'Address': '1044 N. Francisco Ave',
#   'Zip Code': '60622',
#   'Lat': '41.899824000000002',
#   'Lon': '-87.699298999999996',
#   'Community Area': 'WEST TOWN',
#   'Property Type': 'Hospital (General Medical & Surgical)',
#   'Square Feet': '312898',
#   'Year Built': '1917',
#   'Num of Buildings': '2',
#   'Electricity KBTU': '35314234',
#   'Natural Gas KBTU': '34905999',
#   'Site_EUI': '224.4',
#   'Source EUI': '471.5',
#   'Weather Normalized Site EUI': '225.3',
#   'Weather Normalized Source EUI': '469.7',
#   'Emissions': '8949',
#   'Intensity': '28.6'},
#  {'Data Year': '2015',
#   'ID': '106236',
#   'name': 'Mark Twain E-CPS',
#   'Address': '5131 S Linder Ave',
#   'Zip Code': '60638',
#   'Lat': '41.799518999999997',
#   'Lon': '-87.759991999999997',
#   'Community Area': 'GARFIELD RIDGE',
#   'Property Type': 'K-12 School',
#   'Square Feet': '140166',
#   'Year Built': '1927',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '4970049',
#   'Natural Gas KBTU': '4454212',
#   'Site_EUI': '67.2',
#   'Source EUI': '144.69999999999999',
#   'Weather Normalized Site EUI': '70',
#   'Weather Normalized Source EUI': '147.69999999999999',
#   'Emissions': '1235',
#   'Intensity': '8.8000000000000007'},
#  {'Data Year': '2015',
#   'ID': '251925',
#   'name': 'Peter V. Byrne Hall',
#   'Address': '2219 N. Kenmore ',
#   'Zip Code': '60614',
#   'Lat': '41.922072999999997',
#   'Lon': '-87.654664999999994',
#   'Community Area': 'LINCOLN PARK',
#   'Property Type': 'College/University',
#   'Square Feet': '77485',
#   'Year Built': '1968',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2864749',
#   'Natural Gas KBTU': '8017233',
#   'Site_EUI': '140.4',
#   'Source EUI': '224.7',
#   'Weather Normalized Site EUI': '148.9',
#   'Weather Normalized Source EUI': '233.8',
#   'Emissions': '1001',
#   'Intensity': '12.9'},
#  {'Data Year': '2015',
#   'ID': '160248',
#   'name': 'Left Bank at K Station',
#   'Address': '305 N. Canal St',
#   'Zip Code': '60606',
#   'Lat': '41.886954000000003',
#   'Lon': '-87.639858000000004',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '572165',
#   'Year Built': '2006',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '12792195',
#   'Natural Gas KBTU': '23067559',
#   'Site_EUI': '62.7',
#   'Source EUI': '112.5',
#   'Weather Normalized Site EUI': '64.7',
#   'Weather Normalized Source EUI': '113.7',
#   'Emissions': '3795',
#   'Intensity': '6.6'},
#  {'Data Year': '2015',
#   'ID': '120965',
#   'name': '8512-South Loop (16th & Clark)',
#   'Address': '1615 S Clark Street',
#   'Zip Code': '60616',
#   'Lat': '41.859892000000002',
#   'Lon': '-87.630216000000004',
#   'Community Area': 'NEAR SOUTH SIDE',
#   'Property Type': 'Supermarket/Grocery Store',
#   'Square Feet': '61872',
#   'Year Built': '2013',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '10166010',
#   'Natural Gas KBTU': '7337500',
#   'Site_EUI': '282.89999999999998',
#   'Source EUI': '640.4',
#   'Weather Normalized Site EUI': '288',
#   'Weather Normalized Source EUI': '645.79999999999995',
#   'Emissions': '2432',
#   'Intensity': '39.299999999999997'},
#  {'Data Year': '2015',
#   'ID': '250139',
#   'name': 'Domestic Violence Courthouse',
#   'Address': '555 W. Harrison St.',
#   'Zip Code': '60607',
#   'Lat': '41.874352999999999',
#   'Lon': '-87.641660999999999',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Courthouse',
#   'Square Feet': '187268',
#   'Year Built': '1890',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '8819590',
#   'Natural Gas KBTU': '8648514',
#   'Site_EUI': '93.3',
#   'Source EUI': '196.4',
#   'Weather Normalized Site EUI': '97.8',
#   'Weather Normalized Source EUI': '201.3',
#   'Emissions': '2231',
#   'Intensity': '11.9'},
#  {'Data Year': '2015',
#   'ID': '103789',
#   'name': 'De La Salle Institute',
#   'Address': '3434 South Michigan Ave',
#   'Zip Code': '60616',
#   'Lat': '41.832219000000002',
#   'Lon': '-87.623316000000003',
#   'Community Area': 'DOUGLAS',
#   'Property Type': 'K-12 School',
#   'Square Feet': '165000',
#   'Year Built': '1954',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2920502',
#   'Natural Gas KBTU': '8615291',
#   'Site_EUI': '69.900000000000006',
#   'Source EUI': '110.4',
#   'Weather Normalized Site EUI': '73.7',
#   'Weather Normalized Source EUI': '114.4',
#   'Emissions': '1044',
#   'Intensity': '6.3'},
#  {'Data Year': '2015',
#   'ID': '251723',
#   'name': 'James Shield-CPS',
#   'Address': '2611 W 48th St',
#   'Zip Code': '60632',
#   'Lat': '41.806552000000003',
#   'Lon': '-87.689786999999995',
#   'Community Area': 'BRIGHTON PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '95265',
#   'Year Built': '2012',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2940117',
#   'Natural Gas KBTU': '3091825',
#   'Site_EUI': '63.3',
#   'Source EUI': '131',
#   'Weather Normalized Site EUI': '66',
#   'Weather Normalized Source EUI': '133.80000000000001',
#   'Emissions': '755',
#   'Intensity': '7.9'},
#  {'Data Year': '2015',
#   'ID': '251405',
#   'name': 'Hefferan Ele-CPS',
#   'Address': '4409 W Wilcox St',
#   'Zip Code': '60624',
#   'Lat': '41.878708000000003',
#   'Lon': '-87.735789999999994',
#   'Community Area': 'WEST GARFIELD PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '60934',
#   'Year Built': '1961',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1546817',
#   'Natural Gas KBTU': '3395841',
#   'Site_EUI': '81.099999999999994',
#   'Source EUI': '138.19999999999999',
#   'Weather Normalized Site EUI': '85.6',
#   'Weather Normalized Source EUI': '142.9',
#   'Emissions': '491',
#   'Intensity': '8.1'},
#  {'Data Year': '2015',
#   'ID': '251960',
#   'name': 'Latin School of Chicago Middle Scool',
#   'Address': '45 W. North BLVD',
#   'Zip Code': '60610',
#   'Lat': '41.911172000000001',
#   'Lon': '-87.630191999999994',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'K-12 School',
#   'Square Feet': '81509',
#   'Year Built': '2007',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '4068482',
#   'Natural Gas KBTU': '3069300',
#   'Site_EUI': '87.6',
#   'Source EUI': '196.3',
#   'Weather Normalized Site EUI': '89.5',
#   'Weather Normalized Source EUI': '196.8',
#   'Emissions': '980',
#   'Intensity': '12'},
#  {'Data Year': '2015',
#   'ID': '250144',
#   'name': '11 East Adams',
#   'Address': '11 East Adams',
#   'Zip Code': '60603',
#   'Lat': '41.879474000000002',
#   'Lon': '-87.627300000000005',
#   'Community Area': 'LOOP',
#   'Property Type': 'Office',
#   'Square Feet': '161166',
#   'Year Built': '1961',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '7734373',
#   'Natural Gas KBTU': '15042136',
#   'Site_EUI': '141.30000000000001',
#   'Source EUI': '248.7',
#   'Weather Normalized Site EUI': '149',
#   'Weather Normalized Source EUI': '256.8',
#   'Emissions': '2353',
#   'Intensity': '14.6'},
#  {'Data Year': '2015',
#   'ID': '160300',
#   'name': '750 N. Rush',
#   'Address': '750 N. Rush',
#   'Zip Code': '60611',
#   'Lat': '41.896320000000003',
#   'Lon': '-87.625538000000006',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '325000',
#   'Year Built': '1992',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '8409403',
#   'Natural Gas KBTU': '8518707',
#   'Site_EUI': '52.1',
#   'Source EUI': '108.8',
#   'Weather Normalized Site EUI': '52.1',
#   'Weather Normalized Source EUI': '108.7',
#   'Emissions': '2142',
#   'Intensity': '6.6'},
#  {'Data Year': '2015',
#   'ID': '243745',
#   'name': 'Kennelly Square Condominium Association',
#   'Address': '1749 N Wells Street',
#   'Zip Code': '60614',
#   'Lat': '41.914200999999998',
#   'Lon': '-87.634765000000002',
#   'Community Area': 'LINCOLN PARK',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '326596',
#   'Year Built': '1972',
#   'Num of Buildings': '2',
#   'Electricity KBTU': '6936630',
#   'Natural Gas KBTU': '19792801',
#   'Site_EUI': '81.8',
#   'Source EUI': '130.30000000000001',
#   'Weather Normalized Site EUI': '86.2',
#   'Weather Normalized Source EUI': '134.9',
#   'Emissions': '2445',
#   'Intensity': '7.5'},
#  {'Data Year': '2015',
#   'ID': '175683',
#   'name': '03176-Ashland & 95th St',
#   'Address': '9400 S. Ashland Ave',
#   'Zip Code': '60620',
#   'Lat': '41.722799999999999',
#   'Lon': '-87.662757999999997',
#   'Community Area': 'WASHINGTON HEIGHTS',
#   'Property Type': 'Supermarket/Grocery Store',
#   'Square Feet': '66467',
#   'Year Built': '1991',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '10289060',
#   'Natural Gas KBTU': '3898600',
#   'Site_EUI': '213.5',
#   'Source EUI': '547.70000000000005',
#   'Weather Normalized Site EUI': '216.8',
#   'Weather Normalized Source EUI': '549.20000000000005',
#   'Emissions': '2274',
#   'Intensity': '34.200000000000003'},
#  {'Data Year': '2015',
#   'ID': '121374',
#   'name': '8522-Edgewater',
#   'Address': '5201 Sheridan Road',
#   'Zip Code': '60640',
#   'Lat': '41.976491000000003',
#   'Lon': '-87.654964000000007',
#   'Community Area': 'EDGEWATER',
#   'Property Type': 'Supermarket/Grocery Store',
#   'Square Feet': '55129',
#   'Year Built': '2013',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '11152661',
#   'Natural Gas KBTU': '8184000',
#   'Site_EUI': '350.8',
#   'Source EUI': '791.1',
#   'Weather Normalized Site EUI': '355.5',
#   'Weather Normalized Source EUI': '796.1',
#   'Emissions': '2675',
#   'Intensity': '48.5'},
#  {'Data Year': '2015',
#   'ID': '251513',
#   'name': 'Dawes Elemen-CPS',
#   'Address': '3810 W 81st Place',
#   'Zip Code': '60652',
#   'Lat': '41.745032000000002',
#   'Lon': '-87.717214999999996',
#   'Community Area': 'ASHBURN',
#   'Property Type': 'K-12 School',
#   'Square Feet': '84069',
#   'Year Built': '1954',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '581003',
#   'Natural Gas KBTU': '3882419',
#   'Site_EUI': '53.1',
#   'Source EUI': '70.2',
#   'Weather Normalized Site EUI': '57.6',
#   'Weather Normalized Source EUI': '75.7',
#   'Emissions': '323',
#   'Intensity': '3.8'},
#  {'Data Year': '2015',
#   'ID': '103782',
#   'name': 'Warwick Allerton Hotel Chicago',
#   'Address': '701 N. Michigan Ave.',
#   'Zip Code': '60611',
#   'Lat': '41.895220999999999',
#   'Lon': '-87.624213999999995',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Hotel',
#   'Square Feet': '300000',
#   'Year Built': '1924',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '11430644',
#   'Natural Gas KBTU': '28432397',
#   'Site_EUI': '132.9',
#   'Source EUI': '219.2',
#   'Weather Normalized Site EUI': '136.69999999999999',
#   'Weather Normalized Source EUI': '223.1',
#   'Emissions': '3807',
#   'Intensity': '12.7'},
#  {'Data Year': '2015',
#   'ID': '251269',
#   'name': '(IL342) - Century Tower',
#   'Address': '182 W. Lake Street ',
#   'Zip Code': '60601',
#   'Lat': '41.885758000000003',
#   'Lon': '-87.633762000000004',
#   'Community Area': 'LOOP',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '258857',
#   'Year Built': '1930',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '6760407',
#   'Natural Gas KBTU': '17416556',
#   'Site_EUI': '93.4',
#   'Source EUI': '152.69999999999999',
#   'Weather Normalized Site EUI': '93.4',
#   'Weather Normalized Source EUI': '152.69999999999999',
#   'Emissions': '2283',
#   'Intensity': '8.8000000000000007'},
#  {'Data Year': '2015',
#   'ID': '251520',
#   'name': 'Palmer Eleme-CPS',
#   'Address': '5501 N Kenneth Ave',
#   'Zip Code': '60630',
#   'Lat': '41.968167000000001',
#   'Lon': '-87.739169000000004',
#   'Community Area': 'ALBANY PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '91342',
#   'Year Built': '1926',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2123801',
#   'Natural Gas KBTU': '4250579',
#   'Site_EUI': '69.8',
#   'Source EUI': '121.9',
#   'Weather Normalized Site EUI': '71',
#   'Weather Normalized Source EUI': '123.3',
#   'Emissions': '653',
#   'Intensity': '7.1'},
#  {'Data Year': '2015',
#   'ID': '160379',
#   'name': 'Optima Chicago Center',
#   'Address': '200 E Illinios St.',
#   'Zip Code': '60611',
#   'Lat': '41.891016999999998',
#   'Lon': '-87.619777999999997',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '567862',
#   'Year Built': '2014',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '14049217',
#   'Natural Gas KBTU': '12590687',
#   'Site_EUI': '46.9',
#   'Source EUI': '101',
#   'Weather Normalized Site EUI': '47.9',
#   'Weather Normalized Source EUI': '102',
#   'Emissions': '3491',
#   'Intensity': '6.1'},
#  {'Data Year': '2015',
#   'ID': '251722',
#   'name': 'Claremont Ac-CPS',
#   'Address': '6315 S Claremont Ave',
#   'Zip Code': '60636',
#   'Lat': '41.778894999999999',
#   'Lon': '-87.682265000000001',
#   'Community Area': 'CHICAGO LAWN',
#   'Property Type': 'K-12 School',
#   'Square Feet': '112806',
#   'Year Built': '1990',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '3562868',
#   'Natural Gas KBTU': '3123790',
#   'Site_EUI': '59.3',
#   'Source EUI': '128.30000000000001',
#   'Weather Normalized Site EUI': '61.3',
#   'Weather Normalized Source EUI': '130.4',
#   'Emissions': '882',
#   'Intensity': '7.8'},
#  {'Data Year': '2015',
#   'ID': '251786',
#   'name': 'Saint Clement School',
#   'Address': '642 West Deming Place',
#   'Zip Code': '60614',
#   'Lat': '41.927943999999997',
#   'Lon': '-87.645176000000006',
#   'Community Area': 'LINCOLN PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '60994',
#   'Year Built': '1905',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1321669',
#   'Natural Gas KBTU': '4323348',
#   'Site_EUI': '92.6',
#   'Source EUI': '142.5',
#   'Weather Normalized Site EUI': '99.6',
#   'Weather Normalized Source EUI': '149.80000000000001',
#   'Emissions': '495',
#   'Intensity': '8.1'},
# ...
#  {'Data Year': '2017',
#   'ID': '173759',
#   'name': 'Plaza 32 Condominium Association',
#   'Address': '3224-3244 N. Halsted St.',
#   'Zip Code': '60657',
#   'Lat': '41.9398511',
#   'Lon': '-87.65844752',
#   'Community Area': 'LAKE VIEW',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '273284',
#   'Year Built': '2000',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '6517094',
#   'Natural Gas KBTU': '9743637',
#   'Site_EUI': '59.5',
#   'Source EUI': '112.3',
#   'Weather Normalized Site EUI': '62.3',
#   'Weather Normalized Source EUI': '115.2',
#   'Emissions': '1722.5',
#   'Intensity': '6.3'},
#  {'Data Year': '2017',
#   'ID': '173927',
#   'name': 'Catholic Theological Union - Residence Hall',
#   'Address': '5401 S. Cornell Ave.',
#   'Zip Code': '60615',
#   'Lat': '41.79809371',
#   'Lon': '-87.5847824',
#   'Community Area': 'HYDE PARK',
#   'Property Type': 'Residence Hall/Dormitory',
#   'Square Feet': '90770',
#   'Year Built': '1924',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '4340491',
#   'Natural Gas KBTU': '1450700',
#   'Site_EUI': '63.8',
#   'Source EUI': '166.9',
#   'Weather Normalized Site EUI': '67.6',
#   'Weather Normalized Source EUI': '178.9',
#   'Emissions': '879.6',
#   'Intensity': '9.7'},
#  {'Data Year': '2017',
#   'ID': '254327',
#   'name': '3125 W Fullerton',
#   'Address': '3125 W Fullerton Avenue',
#   'Zip Code': '60610',
#   'Lat': '41.9172389',
#   'Lon': '-87.6849',
#   'Community Area': 'Logan Square',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '155000',
#   'Year Built': '2007',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2589380',
#   'Natural Gas KBTU': '3652253',
#   'Site_EUI': '40.3',
#   'Source EUI': '77.2',
#   'Weather Normalized Site EUI': '42.1',
#   'Weather Normalized Source EUI': '79.1',
#   'Emissions': '672.8',
#   'Intensity': '4.3'},
#  {'Data Year': '2017',
#   'ID': '244182',
#   'name': 'Park Place Tower: 655 West Irving Park Road',
#   'Address': '655 West Irving Park Road',
#   'Zip Code': '60613',
#   'Lat': '41.95381635',
#   'Lon': '-87.64691335',
#   'Community Area': 'LAKE VIEW',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '989315',
#   'Year Built': '1974',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '23937954',
#   'Natural Gas KBTU': '61801933',
#   'Site_EUI': '86.7',
#   'Source EUI': '141.6',
#   'Weather Normalized Site EUI': '92.4',
#   'Weather Normalized Source EUI': '146.8',
#   'Emissions': '7708.6',
#   'Intensity': '7.8'},
#  {'Data Year': '2017',
#   'ID': '255002',
#   'name': '53100539 -- Chicago',
#   'Address': '3857 South Dr. Martin Luther King Jr. Drive',
#   'Zip Code': '60653',
#   'Lat': '41.8149269',
#   'Lon': '-87.6184709',
#   'Community Area': 'Douglas',
#   'Property Type': 'Supermarket/Grocery Store',
#   'Square Feet': '72115',
#   'Year Built': '2016',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '9095652',
#   'Natural Gas KBTU': '10601287',
#   'Site_EUI': '273.1',
#   'Source EUI': '550.4',
#   'Weather Normalized Site EUI': '279.8',
#   'Weather Normalized Source EUI': '555.1',
#   'Emissions': '2244.8',
#   'Intensity': '31.1'},
#  {'Data Year': '2017',
#   'ID': '250058',
#   'name': 'MARTIN LUTHER KING COMMUNITY CENTER',
#   'Address': '4314 S. Cottage Grove Ave.',
#   'Zip Code': '60653',
#   'Lat': '41.81634122',
#   'Lon': '-87.60674817',
#   'Community Area': 'GRAND BOULEVARD',
#   'Property Type': 'Other - Entertainment/Public Assembly',
#   'Square Feet': '56687',
#   'Year Built': '1975',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2757142',
#   'Natural Gas KBTU': '3362570',
#   'Site_EUI': '108',
#   'Source EUI': '215',
#   'Weather Normalized Site EUI': '114.8',
#   'Weather Normalized Source EUI': '222.7',
#   'Emissions': '688.4',
#   'Intensity': '12.1'},
#  {'Data Year': '2017',
#   'ID': '159649',
#   'name': 'Belmont Tower',
#   'Address': '510 West Belmont Avenue',
#   'Zip Code': '60657',
#   'Lat': '41.94030774',
#   'Lon': '-87.64275862',
#   'Community Area': 'LAKE VIEW',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '279147',
#   'Year Built': '1970',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '4433157',
#   'Natural Gas KBTU': '21350000',
#   'Site_EUI': '92.4',
#   'Source EUI': '130.2',
#   'Weather Normalized Site EUI': '97.3',
#   'Weather Normalized Source EUI': '135.4',
#   'Emissions': '1953.7',
#   'Intensity': '7'},
#  {'Data Year': '2017',
#   'ID': '160342',
#   'name': 'The Seneca',
#   'Address': '200 E Chestnut Street',
#   'Zip Code': '60611',
#   'Lat': '41.89861832',
#   'Lon': '-87.62140976',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '168457',
#   'Year Built': '1922',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '6232956',
#   'Natural Gas KBTU': '24393767',
#   'Site_EUI': '181.8',
#   'Source EUI': '268.2',
#   'Weather Normalized Site EUI': '190.4',
#   'Weather Normalized Source EUI': '276.8',
#   'Emissions': '2448.1',
#   'Intensity': '14.5'},
#  {'Data Year': '2017',
#   'ID': '101729',
#   'name': '540 West Madison',
#   'Address': '540 W. Madison',
#   'Zip Code': '60661',
#   'Lat': '41.88256638',
#   'Lon': '-87.6416484',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Financial Office',
#   'Square Feet': '1222281',
#   'Year Built': '2004',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '89191557',
#   'Natural Gas KBTU': '442307',
#   'Site_EUI': '73.3',
#   'Source EUI': '229.5',
#   'Weather Normalized Site EUI': '77.8',
#   'Weather Normalized Source EUI': '243.6',
#   'Emissions': '16514.5',
#   'Intensity': '13.5'},
#  {'Data Year': '2017',
#   'ID': '133957',
#   'name': 'Capitol Hill Lofts',
#   'Address': '625 W Jackson',
#   'Zip Code': '60661',
#   'Lat': '41.88321395',
#   'Lon': '-87.64336601',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '120000',
#   'Year Built': '1918',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2575852',
#   'Natural Gas KBTU': '4051059',
#   'Site_EUI': '55.2',
#   'Source EUI': '102.8',
#   'Weather Normalized Site EUI': '57.7',
#   'Weather Normalized Source EUI': '105',
#   'Emissions': '691.4',
#   'Intensity': '5.8'},
#  {'Data Year': '2017',
#   'ID': '100393',
#   'name': 'Ford City Mall',
#   'Address': '7601 S Cicero Ave',
#   'Zip Code': '60652',
#   'Lat': '41.75582921',
#   'Lon': '-87.73699268',
#   'Community Area': 'WEST LAWN',
#   'Property Type': 'Enclosed Mall',
#   'Square Feet': '864923',
#   'Year Built': '1950',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '142925541',
#   'Natural Gas KBTU': '53244653',
#   'Site_EUI': '226.8',
#   'Source EUI': '583.5',
#   'Weather Normalized Site EUI': '224.4',
#   'Weather Normalized Source EUI': '576',
#   'Emissions': '29254.3',
#   'Intensity': '33.8'},
#  {'Data Year': '2017',
#   'ID': '254386',
#   'name': 'Halas Recreation Center- ID# 254386',
#   'Address': '6458 N Winthrop Ave',
#   'Zip Code': '60626',
#   'Lat': '42.00660309',
#   'Lon': '-87.66729325',
#   'Community Area': 'Rogers Park',
#   'Property Type': 'College/University',
#   'Square Feet': '122180',
#   'Year Built': '1982',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '5261423',
#   'Natural Gas KBTU': '6395016',
#   'Site_EUI': '95.4',
#   'Source EUI': '190.2',
#   'Weather Normalized Site EUI': '99.2',
#   'Weather Normalized Source EUI': '193.2',
#   'Emissions': '1312.5',
#   'Intensity': '10.7'},
#  {'Data Year': '2017',
#   'ID': '172298',
#   'name': 'CAIII Condominium Association (122-134 S. Aberdeen and 1100 W. Adams)',
#   'Address': '122-134 S. Aberdeen',
#   'Zip Code': '60614',
#   'Lat': '41.87921245',
#   'Lon': '-87.65673552',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '120000',
#   'Year Built': '2015',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1613105',
#   'Natural Gas KBTU': '3526465',
#   'Site_EUI': '42.8',
#   'Source EUI': '73.1',
#   'Weather Normalized Site EUI': '45.6',
#   'Weather Normalized Source EUI': '76.1',
#   'Emissions': '485.6',
#   'Intensity': '4'},
#  {'Data Year': '2017',
#   'ID': '251235',
#   'name': '110 E. Delaware CA',
#   'Address': '110 E. Delaware Place',
#   'Zip Code': '60611',
#   'Lat': '41.8992147',
#   'Lon': '-87.62541324',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '95220',
#   'Year Built': '1981',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2878165',
#   'Natural Gas KBTU': '1486777',
#   'Site_EUI': '45.8',
#   'Source EUI': '111.3',
#   'Weather Normalized Site EUI': '47.1',
#   'Weather Normalized Source EUI': '114.7',
#   'Emissions': '611.1',
#   'Intensity': '6.4'},
#  {'Data Year': '2017',
#   'ID': '112395',
#   'name': '3600 Pine Grove Court Condominium Association',
#   'Address': '3600-3608 N. Pine Grove Ave.',
#   'Zip Code': '60613',
#   'Lat': '41.95402016',
#   'Lon': '-87.6620278',
#   'Community Area': 'LAKE VIEW',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '52015',
#   'Year Built': '1925',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '786443',
#   'Natural Gas KBTU': '3485992',
#   'Site_EUI': '82.1',
#   'Source EUI': '117.8',
#   'Weather Normalized Site EUI': '88.4',
#   'Weather Normalized Source EUI': '124.4',
#   'Emissions': '330.6',
#   'Intensity': '6.4'},
#  {'Data Year': '2017',
#   'ID': '112724',
#   'name': '6119 6125 N Winchester',
#   'Address': '6119-6125 N Winchester Ave',
#   'Zip Code': '60660',
#   'Lat': '41.99090057',
#   'Lon': '-87.66660744',
#   'Community Area': 'WEST RIDGE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '57600',
#   'Year Built': '1951',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1380021',
#   'Natural Gas KBTU': '6909000',
#   'Site_EUI': '143.9',
#   'Source EUI': '201.2',
#   'Weather Normalized Site EUI': '157.4',
#   'Weather Normalized Source EUI': '215.6',
#   'Emissions': '622.1',
#   'Intensity': '10.8'},
#  {'Data Year': '2017',
#   'ID': '104838',
#   'name': '421-31 Barry',
#   'Address': '421-31 W Barry Ave.',
#   'Zip Code': '60657',
#   'Lat': '41.9398511',
#   'Lon': '-87.65844752',
#   'Community Area': 'LAKE VIEW',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '60472',
#   'Year Built': '1969',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1300150',
#   'Natural Gas KBTU': '4998838',
#   'Site_EUI': '104.2',
#   'Source EUI': '154.3',
#   'Weather Normalized Site EUI': '110.1',
#   'Weather Normalized Source EUI': '159.8',
#   'Emissions': '505.9',
#   'Intensity': '8.4'},
#  {'Data Year': '2017',
#   'ID': '252034',
#   'name': 'Center Home For Hispanic Elderly',
#   'Address': '1401 N. California Ave',
#   'Zip Code': '60622',
#   'Lat': '41.90676046',
#   'Lon': '-87.69632541',
#   'Community Area': 'WEST TOWN',
#   'Property Type': 'Senior Care Community',
#   'Square Feet': '75000',
#   'Year Built': '1925',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2161149',
#   'Natural Gas KBTU': '10542694',
#   'Site_EUI': '169.4',
#   'Source EUI': '238.1',
#   'Weather Normalized Site EUI': '172.6',
#   'Weather Normalized Source EUI': '240.7',
#   'Emissions': '959.6',
#   'Intensity': '12.8'},
#  {'Data Year': '2017',
#   'ID': '254061',
#   'name': '6700 Crandon Condominium Association',
#   'Address': '6700 S. Crandon',
#   'Zip Code': '60649',
#   'Lat': '41.7626302',
#   'Lon': '-87.57255',
#   'Community Area': 'South Shore',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '82000',
#   'Year Built': '1928',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '859735',
#   'Natural Gas KBTU': '10374950',
#   'Site_EUI': '137',
#   'Source EUI': '165.8',
#   'Weather Normalized Site EUI': '149.5',
#   'Weather Normalized Source EUI': '178.9',
#   'Emissions': '710',
#   'Intensity': '8.7'},
#  {'Data Year': '2017',
#   'ID': '100674',
#   'name': 'The Lofts at Arthington',
#   'Address': '3301 West Arthington Street',
#   'Zip Code': '60624',
#   'Lat': '41.87000549',
#   'Lon': '-87.70831909',
#   'Community Area': 'NORTH LAWNDALE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '228897',
#   'Year Built': '1909',
#   'Num of Buildings': '2',
#   'Electricity KBTU': '2564975',
#   'Natural Gas KBTU': '8642221',
#   'Site_EUI': '49',
#   'Source EUI': '74.8',
#   'Weather Normalized Site EUI': '52.6',
#   'Weather Normalized Source EUI': '78.7',
#   'Emissions': '933.3',
#   'Intensity': '4.1'},
#  {'Data Year': '2017',
#   'ID': '252076',
#   'name': 'Acero School - Officer Donald J. Marquez',
#   'Address': '2916 W. 47th St.',
#   'Zip Code': '60632',
#   'Lat': '41.80856277',
#   'Lon': '-87.69718607',
#   'Community Area': 'BRIGHTON PARK',
#   'Property Type': 'K-12 School',
#   'Square Feet': '58150',
#   'Year Built': '2007',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '2752204',
#   'Natural Gas KBTU': '934234',
#   'Site_EUI': '63.4',
#   'Source EUI': '165.5',
#   'Weather Normalized Site EUI': '67.7',
#   'Weather Normalized Source EUI': '173.1',
#   'Emissions': '558.5',
#   'Intensity': '9.6'},
#  {'Data Year': '2017',
#   'ID': '110254',
#   'name': '110 West Superior, LLC',
#   'Address': '110 W. Superior St.',
#   'Zip Code': '60654',
#   'Lat': '41.89158015',
#   'Lon': '-87.63783734',
#   'Community Area': 'NEAR NORTH SIDE',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '117495',
#   'Year Built': '2009',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '4290402',
#   'Natural Gas KBTU': '6870067',
#   'Site_EUI': '95',
#   'Source EUI': '176.1',
#   'Weather Normalized Site EUI': '103.9',
#   'Weather Normalized Source EUI': '190.8',
#   'Emissions': '1158.2',
#   'Intensity': '9.9'},
#  {'Data Year': '2017',
#   'ID': '175793',
#   'name': '811 E. 46th',
#   'Address': '811 E. 46th St',
#   'Zip Code': '60619',
#   'Lat': '41.82021138',
#   'Lon': '-87.61246867',
#   'Community Area': 'KENWOOD',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '74287',
#   'Year Built': '1921',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '178267',
#   'Natural Gas KBTU': '208483',
#   'Site_EUI': '5.2',
#   'Source EUI': '10.5',
#   'Weather Normalized Site EUI': '5.4',
#   'Weather Normalized Source EUI': '11',
#   'Emissions': '44',
#   'Intensity': '0.6'},
#  {'Data Year': '2017',
#   'ID': '119609',
#   'name': 'Universal Building, 700 N Sacramento',
#   'Address': '700 N Sacramento',
#   'Zip Code': '60612',
#   'Lat': '41.89395442',
#   'Lon': '-87.70275245',
#   'Community Area': 'HUMBOLDT PARK',
#   'Property Type': 'Office',
#   'Square Feet': '149585',
#   'Year Built': '1901',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '4342992',
#   'Natural Gas KBTU': '3197056',
#   'Site_EUI': '50.4',
#   'Source EUI': '113.6',
#   'Weather Normalized Site EUI': '54.3',
#   'Weather Normalized Source EUI': '117.1',
#   'Emissions': '972.8',
#   'Intensity': '6.5'},
#  {'Data Year': '2017',
#   'ID': '115341',
#   'name': '4880 Marine Drive Condominium',
#   'Address': '4880 N Marine Dr',
#   'Zip Code': '60640',
#   'Lat': '41.97223008',
#   'Lon': '-87.6645957',
#   'Community Area': 'UPTOWN',
#   'Property Type': 'Multifamily Housing',
#   'Square Feet': '70625',
#   'Year Built': '1958',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '1280240',
#   'Natural Gas KBTU': '6284866',
#   'Site_EUI': '107.1',
#   'Source EUI': '150.4',
#   'Weather Normalized Site EUI': '115.6',
#   'Weather Normalized Source EUI': '159.5',
#   'Emissions': '570.5',
#   'Intensity': '8.1'},
#  {'Data Year': '2017',
#   'ID': '254170',
#   'name': 'San Francisco Hall-ID# 254170',
#   'Address': '6327 N Kenmore Ave',
#   'Zip Code': '60626',
#   'Lat': '41.99723585',
#   'Lon': '-87.65688616',
#   'Community Area': 'Edgewater',
#   'Property Type': 'Residence Hall/Dormitory',
#   'Square Feet': '92000',
#   'Year Built': '2013',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '3896470',
#   'Natural Gas KBTU': '168452',
#   'Site_EUI': '44.2',
#   'Source EUI': '134.9',
#   'Weather Normalized Site EUI': '45.1',
#   'Weather Normalized Source EUI': '137.8',
#   'Emissions': '729.4',
#   'Intensity': '7.9'},
#  {'Data Year': '2015',
#   'ID': '250009',
#   'name': 'Malcolm X College',
#   'Address': '1900 West Van Buren Street',
#   'Zip Code': '60612',
#   'Lat': '41.876251000000003',
#   'Lon': '-87.674126999999999',
#   'Community Area': 'NEAR WEST SIDE',
#   'Property Type': 'College/University',
#   'Square Feet': '541575',
#   'Year Built': '1971',
#   'Num of Buildings': '1',
#   'Electricity KBTU': '25403152',
#   'Natural Gas KBTU': '29511031',
#   'Site_EUI': '101.4',
#   'Source EUI': '204.5',
#   'Weather Normalized Site EUI': '105.5',
#   'Weather Normalized Source EUI': '208.1',
#   'Emissions': '6671',
#   'Intensity': '12.3'}]

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")
weather_data.to_sql(name='hawaii', con=cnx)
pd.read_sql_table(table_name='hawaii', con=e)

# %%
import sqlite3
# Create your connection.
cnx = sqlite3.connect(':memory:')
weather_data.to_sql(name='hawaii', con=cnx)
w2 = pd.read_sql_table(table_name='hawaii', con=e)
w2.Date = pd.to_datetime(w2.Date)
w = w2.set_index('Date')
